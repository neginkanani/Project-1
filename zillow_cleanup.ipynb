# %%
#Begain clean up process by converting excel to csv via save as feature

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

#path to zillow data
zillow_data_path = "Raw_Data_VL/US MSA Rent Rate Data 2015-2022.csv"

# Read data
zillow_data = pd.read_csv(zillow_data_path)
zillow_data.head()

#get unneeded time points
list(zillow_data.columns)

dates = [ '3/31/15',
 '4/30/15','5/31/15','6/30/15','7/31/15','8/31/15','9/30/15','10/31/15','11/30/15','12/31/15','1/31/16',
 '2/29/16','3/31/16','4/30/16','5/31/16','6/30/16','7/31/16','8/31/16','9/30/16','10/31/16','11/30/16',
 '12/31/16','1/31/17','2/28/17','3/31/17','4/30/17','5/31/17','6/30/17','7/31/17','8/31/17','9/30/17',
 '10/31/17','11/30/17','12/31/17','1/31/18','2/28/18','3/31/18','4/30/18','5/31/18','6/30/18','7/31/18','8/31/18',
 '9/30/18','10/31/18','11/30/18','12/31/18','1/31/19','2/28/19','3/31/19',
 '4/30/19','5/31/19','6/30/19','7/31/19','8/31/19','9/30/19','10/31/19','11/30/19','12/31/19',]

zillow_2020 = zillow_data.drop(columns = dates)
zillow_2020.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName      1/31/20  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County  2866.742067
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  2499.153587
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County  1408.121935
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County  1706.930665
# 4          San Antonio-New Braunfels, TX        Bexar County  1175.137813
#
#        2/29/20  ...      3/31/22      4/30/22      5/31/22      6/30/22  \
# ...

# %%
#filter to cites in review
#Sacremeno California
#Atlanta Georgia
#Austin Texas

# %%
#identify all the columns titles #https://www.geeksforgeeks.org/how-to-get-column-names-in-pandas-dataframe/


#https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/
#https://www.w3resource.com/pandas/dataframe/dataframe-drop.php
#Whether to drop labels from the index (0 or ‘index’) or columns (1 or ‘columns’).

#remove un-needed time points 2015-2019
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j2/6yl2nxb11rdc4c21ddg9t7280000gn/T/ipykernel_3773/1727670076.py in <module>
#       7
#       8 #remove un-needed time points 2015-2019
# ----> 9 zillow_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
